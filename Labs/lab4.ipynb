# %% [markdown]
# # Lab 4: NAIVE BAYE'S CLASSIFICATION ALGORITHM

# %%
# %pip install scikit-learn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Q1.

# %%
import pandas as pd
data = pd.read_csv("Datasets/Heart_Dataset.csv")
data
# Out:
#      Age Gender ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40      M           ATA        140          289          0     Normal
# 1     49      F           NAP        160          180          0     Normal
# 2     37      M           ATA        130          283          0         ST
# 3     48      F           ASY        138          214          0     Normal
# 4     54      M           NAP        150          195          0     Normal
# ..   ...    ...           ...        ...          ...        ...        ...
# 913   45      M            TA        110          264          0     Normal
# 914   68      M           ASY        144          193          1     Normal
# 915   57      M           ASY        130          131          0     Normal
# 916   57      F           ATA        130          236          0        LVH
# 917   38      M           NAP        138          175          0     Normal
#
# ...

# %%
X = data.drop(columns='HeartDisease')
X
# Out:
#      Age Gender ChestPainType  RestingBP  Cholesterol  FastingBS RestingECG  \
# 0     40      M           ATA        140          289          0     Normal
# 1     49      F           NAP        160          180          0     Normal
# 2     37      M           ATA        130          283          0         ST
# 3     48      F           ASY        138          214          0     Normal
# 4     54      M           NAP        150          195          0     Normal
# ..   ...    ...           ...        ...          ...        ...        ...
# 913   45      M            TA        110          264          0     Normal
# 914   68      M           ASY        144          193          1     Normal
# 915   57      M           ASY        130          131          0     Normal
# 916   57      F           ATA        130          236          0        LVH
# 917   38      M           NAP        138          175          0     Normal
#
#      MaxHR ExerciseAngina  Oldpeak ST_Slope
# ...

# %%
Y = data['HeartDisease']

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Gender          918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
# dtypes: float64(1), int64(5), object(5)
# memory usage: 79.0+ KB

# %%
X['Gender'].unique()
X['Gender'] = X['Gender'].replace('M', 1)
X['Gender'] = X['Gender'].replace('F', 0)
# Out:
# /var/folders/_8/stmfqx710clbn04z1vg4j8lr0000gn/T/ipykernel_2386/1690155209.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['Gender'] = X['Gender'].replace('F', 0)

# %%
X['ChestPainType'].unique()
X['ChestPainType'] = X['ChestPainType'].replace('ATA', 1)
X['ChestPainType'] = X['ChestPainType'].replace('NAP', 2)
X['ChestPainType'] = X['ChestPainType'].replace('ASY', 3)
X['ChestPainType'] = X['ChestPainType'].replace('TA', 4)
# Out:
# /var/folders/_8/stmfqx710clbn04z1vg4j8lr0000gn/T/ipykernel_2386/4037235785.py:5: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['ChestPainType'] = X['ChestPainType'].replace('TA', 4)

# %%
X['RestingECG'].unique()
X['RestingECG']=X['RestingECG'].replace('Normal',1)
X['RestingECG']=X['RestingECG'].replace('ST',2)
X['RestingECG']=X['RestingECG'].replace('LVH',3)
# Out:
# /var/folders/_8/stmfqx710clbn04z1vg4j8lr0000gn/T/ipykernel_2386/1955802604.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['RestingECG']=X['RestingECG'].replace('LVH',3)

# %%
X['ExerciseAngina'].unique()
X['ExerciseAngina']=X['ExerciseAngina'].replace('N',0)
X['ExerciseAngina']=X['ExerciseAngina'].replace('Y',1)
# Out:
# /var/folders/_8/stmfqx710clbn04z1vg4j8lr0000gn/T/ipykernel_2386/3307547026.py:3: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['ExerciseAngina']=X['ExerciseAngina'].replace('Y',1)

# %%
X['ST_Slope'].unique()
X['ST_Slope'] = X['ST_Slope'].replace('Up', 1)
X['ST_Slope'] = X['ST_Slope'].replace('Flat', 2)
X['ST_Slope'] = X['ST_Slope'].replace('Down', 3)
# Out:
# /var/folders/_8/stmfqx710clbn04z1vg4j8lr0000gn/T/ipykernel_2386/3117472533.py:4: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   X['ST_Slope'] = X['ST_Slope'].replace('Down', 3)

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    int64
#  1   Gender          918 non-null    int64
#  2   ChestPainType   918 non-null    int64
#  3   RestingBP       918 non-null    int64
#  4   Cholesterol     918 non-null    int64
#  5   FastingBS       918 non-null    int64
#  6   RestingECG      918 non-null    int64
#  7   MaxHR           918 non-null    int64
#  8   ExerciseAngina  918 non-null    int64
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    int64
# dtypes: float64(1), int64(10)
# memory usage: 79.0 KB

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, random_state=0, test_size=0.2)
print(X_train.shape, Y_train.shape, X_test.shape, Y_test.shape, sep='\n')
# Out:
# (734, 11)
# (734,)
# (184, 11)
# (184,)

# %%
from sklearn.naive_bayes import GaussianNB, BernoulliNB, MultinomialNB
classifier1 = GaussianNB()
classifier1.fit(X_train, Y_train)
# Out:
# GaussianNB()

# %% [markdown]
# # Q2.

# %%
from sklearn.metrics import accuracy_score, confusion_matrix, recall_score, precision_score, roc_auc_score

pred_Y = classifier1.predict(X_test)
print("The accuracy is", accuracy_score(Y_test, pred_Y)*100, "%")
print("The recall score is", recall_score(Y_test, pred_Y)*100, "%")
print("The precision is", precision_score(Y_test, pred_Y)*100, "%")
print("The roc score is", roc_auc_score(Y_test, pred_Y)*100, "%")
confusion_matrix(Y_test, pred_Y)
# Out:
# The accuracy is 83.15217391304348 %
# The recall score is 86.91588785046729 %
# The precision is 84.54545454545455 %
# The roc score is 82.4189828862726 %
# array([[60, 17],
#        [14, 93]])

# %% [markdown]
# # Q3.

# %%
classifier25 = GaussianNB(priors=[0.25, 0.75])
classifier25.fit(X_train, Y_train)
# Out:
# GaussianNB(priors=[0.25, 0.75])

# %%
pred_Y25 = classifier25.predict(X_test)
print("The accuracy is", accuracy_score(Y_test, pred_Y25)*100, "%")
confusion_matrix(Y_test, pred_Y25)
# Out:
# The accuracy is 84.23913043478261 %
# array([[58, 19],
#        [10, 97]])

# %%
classifier75 = GaussianNB(priors=[0.75, 0.25])
classifier75.fit(X_train, Y_train)
# Out:
# GaussianNB(priors=[0.75, 0.25])

# %%
pred_Y75 = classifier75.predict(X_test)
print("The accuracy is", accuracy_score(Y_test, pred_Y75)*100, "%")
confusion_matrix(Y_test, pred_Y75)
# Out:
# The accuracy is 83.69565217391305 %
# array([[63, 14],
#        [16, 91]])

# %%
classifier50 = GaussianNB(priors=[0.5, 0.5])
classifier50.fit(X_train, Y_train)
# Out:
# GaussianNB(priors=[0.5, 0.5])

# %%
pred_Y50 = classifier50.predict(X_test)
print("The accuracy is", accuracy_score(Y_test, pred_Y50)*100, "%")
confusion_matrix(Y_test, pred_Y50)
# Out:
# The accuracy is 83.69565217391305 %
# array([[61, 16],
#        [14, 93]])

# %% [markdown]
# # Q4.

# %%
classifier3 = BernoulliNB()
classifier3.fit(X_train, Y_train)
# Out:
# BernoulliNB()

# %%
pred_Y3 = classifier3.predict(X_test)
print("The accuracy is", accuracy_score(Y_test, pred_Y3)*100, "%")
confusion_matrix(Y_test, pred_Y3)
# Out:
# The accuracy is 79.34782608695652 %
# array([[59, 18],
#        [20, 87]])

# %%
X_Multi = X.drop(columns=['Age', 'RestingBP', 'Cholesterol', 'MaxHR', 'Oldpeak'])
X_Multi
# Out:
#      Gender  ChestPainType  FastingBS  RestingECG  ExerciseAngina  ST_Slope
# 0         1              1          0           1               0         1
# 1         0              2          0           1               0         2
# 2         1              1          0           2               0         1
# 3         0              3          0           1               1         2
# 4         1              2          0           1               0         1
# ..      ...            ...        ...         ...             ...       ...
# 913       1              4          0           1               0         2
# 914       1              3          1           1               0         2
# 915       1              3          0           1               1         2
# 916       0              1          0           3               0         2
# 917       1              2          0           1               0         1
#
# [918 rows x 6 columns]

# %%
X_train1, X_test1, Y_train1, Y_test1 = train_test_split(X_Multi, Y, random_state=0, test_size=0.2)
print(X_train1.shape, Y_train1.shape, X_test1.shape, Y_test1.shape, sep='\n')
# Out:
# (734, 6)
# (734,)
# (184, 6)
# (184,)

# %%
classifier4 = MultinomialNB()
classifier4.fit(X_train1, Y_train1)
# Out:
# MultinomialNB()

# %%
pred_Y4 = classifier4.predict(X_test1)
print("The accuracy is", accuracy_score(Y_test1, pred_Y4)*100, "%")
confusion_matrix(Y_test1, pred_Y4)
# Out:
# The accuracy is 76.63043478260869 %
# array([[56, 21],
#        [22, 85]])

# %% [markdown]
# # Q5.

# %%
# %pip install ucimlrepo
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from ucimlrepo import fetch_ucirepo

# %%
spambase = fetch_ucirepo(id=94) 
X = spambase.data.features 
y = spambase.data.targets

# %%
x_trainspam, x_testspam, y_trainspam, y_testspam = train_test_split(X, y, random_state=0, test_size=0.2)
print(x_trainspam.shape, x_testspam.shape, y_trainspam.shape, y_testspam.shape, sep='\n')
# Out:
# (3680, 57)
# (921, 57)
# (3680, 1)
# (921, 1)

# %%
classifier_spam = GaussianNB()
classifier_spam.fit(x_trainspam, y_trainspam)
# Out:
# /Users/aqibaabdulqadir/Desktop/MachineLearning/.venv/lib/python3.13/site-packages/sklearn/utils/validation.py:1408: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GaussianNB()

# %%
pred_Yspam = classifier_spam.predict(x_testspam)
pred_Y = classifier1.predict(X_test)
print("The accuracy is", accuracy_score(y_testspam, pred_Yspam)*100, "%")
print("The recall score is", recall_score(y_testspam, pred_Yspam)*100, "%")
print("The precision is", precision_score(y_testspam, pred_Yspam)*100, "%")
print("The roc score is", roc_auc_score(y_testspam, pred_Yspam)*100, "%")

confusion_matrix(y_testspam, pred_Yspam)
# Out:
# The accuracy is 80.67318132464713 %
# The recall score is 93.21148825065274 %
# The precision is 70.13752455795678 %
# The roc score is 82.47935007328175 %
# array([[386, 152],
#        [ 26, 357]])

# %% [markdown]
# # Q6.

# %%
# See Lab 3
